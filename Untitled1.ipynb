# %% [markdown]
# # ELECTION ANALYSIS AND PREDICTION - INDIA

# %% [markdown]
# # 1. PROBLEM STATEMENT

# %% [markdown]
# This project aims to identify the factors which play a substantial role in deciding the winning candidature in the Indian elections. Using Linear Regression, we calculate a "score" and assign it to each candidate contesting the election. The score is a correlation of the candidate's chances of winning or losing. <br> <br>
# We further calculate feature importance using Random Forest Algorithm to determine which features significantly dominate in curating this model's result.

# %% [markdown]
# # 2. BACKGROUND

# %% [markdown]
# India holds the general elections for the lower house of the parliament after every five years. Elections are held over 543 seats (total number of elected candidates) across 29 states and 7 Union Territories. With over 900 million eligible voters and more than 7000 candidates in 2019, the general elections in India are the largest in the world. <br> <br>
# The data for the 2019 elections has not yet been published by the Election Commission of India. For this project, the available data from 2004, 2009 and 2014 elections is used.

# %% [markdown]
# # 3. DATA

# %% [markdown]
# ## 3.1 DATA COLLECTION

# %% [markdown]
# The dataset used in the project has been scraped from https://www.myneta.info/ <br>
# The website has the database of all candidates contesting for the general elections in 2004, 2009 and 2014. <br>
# The respective links for the datasets of candidates for the three years are: <br>
# 1. 2004 elections: http://myneta.info/ls2004/
# 2. 2009 elections: http://myneta.info/ls2009/
# 3. 2014 elections: http://myneta.info/ls2014/<br>
#
# According to the mentioned website :  "The primary source for the data used for these reports is the sworn affidavits provided by the candidates themselves" <br>
#
# The following is the code for the scraper:

# %% [markdown]
# ### Importing Libraries for the project

# %% [markdown]
# #### Note: Some packages will require installation by using the pip command. Packages can be installed by uncommenting code in the subsequent code block in case of an error

# %%
#uncomment if package installation is required
# import sys
# !{sys.executable} -m pip install pyquery

# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from pyquery import PyQuery as pq
import requests
import time

import matplotlib
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3.1.1 URL Definition

# %%
base_2014 = "http://myneta.info/ls2014/"
base_2009 = "http://myneta.info/ls2009/"
base_2004 = "http://myneta.info/loksabha2004/"

#url_list={'2004':ls_2004,'2009':ls_2009,'2014':ls_2014}
base_urls = {'2004':base_2004,'2009':base_2009,'2014':base_2014}

# %% [markdown]
# ### 3.1.2 Key functions to get data

# %% [markdown]
# #### The following function returns a dataframe of constituencies within a state

# %%
def get_constituents(year, thelink):
    print("Fetching constituencies!")
    html = requests.get(thelink)
    doc = pq(html.content)
    trs = doc('table').eq(2).find('tr')
    datalist=[]
    for tr in trs:
        new_state = pq(tr)('th').text()
        if new_state != "":
            curr_state = new_state 
            #print("state:", curr_state)
        else:
            districts = pq(tr)('td')
            if districts != "":
                for x in districts:
                    dist_name = pq(x)('a').text()
                    if dist_name != "":
                        district_dict = {'year':year, 'state':curr_state}
                        district_dict['district'] = dist_name
                        district_dict['thelink'] = pq(x)('a').attr.href
                        datalist.append(district_dict)
                        
    print("PROCESS COMPLETED FOR YEAR:", year)
    print("TOTAL CONSTITUENCIES", len(datalist))


    return pd.DataFrame(datalist)

# %% [markdown]
# #### The following functions returns a dataframe of candidates from a constituency####

# %%
def get_candidates(constituency, state, thelink, year):

    masterlink = thelink
    thepage = requests.get(masterlink)
    doc = pq(thepage.content)

    trs = doc('table').eq(2).children('tr')

    #print pq(trs)
    datalist = []

    for tr in trs[1:]:
        candidate_dict = {'Year':year, 'State':state, 'Constituency':constituency, 'Winner': 0}
        for i,td in enumerate(pq(tr)('td')):
            if i == 0:
                candidate_dict['Name'] = pq(td)('a').text()
                candidate_dict['Link'] = pq(td)('a').attr.href
                if pq(td)('font').text() == "Winner":
                    candidate_dict['Winner'] = 1
            if i == 1:
                candidate_dict['Party'] = pq(td).text()
            if i == 2:
                candidate_dict['Criminal_Cases'] = pq(td).text()
            if i == 3:
                candidate_dict['Education'] = pq(td).text()                
            if i == 4:
                candidate_dict['Age'] = pq(td).text() 
            if i == 5:
                candidate_dict['Assets_Rs'] = td.text.replace("Rs",'').replace(',','').lstrip()
            if i == 6:
                candidate_dict['Liabilities_Rs'] = td.text.replace("Rs",'').replace(',','').lstrip()
        datalist.append(candidate_dict)
    return pd.DataFrame(datalist)

# %% [markdown]
# ### 3.1.3 Putting it all together

# %% [markdown]
# #### Getting all the constituencies####

# %%
# %%time
constituency_list = []

for year, url in base_urls.items():
    constituency_list.append(get_constituents(year, url))
constituency_df = pd.concat(constituency_list)
# Out:
# Fetching constituencies!
# PROCESS COMPLETED FOR YEAR: 2004
# TOTAL CONSTITUENCIES 543
# Fetching constituencies!
# PROCESS COMPLETED FOR YEAR: 2009
# TOTAL CONSTITUENCIES 543
# Fetching constituencies!
# PROCESS COMPLETED FOR YEAR: 2014
# TOTAL CONSTITUENCIES 543
# CPU times: user 405 ms, sys: 16.6 ms, total: 421 ms
# Wall time: 8.16 s

# %% [markdown]
# #### Getting candidates for each constituency
# (Time consuming, can skip and read "candidates.csv" from the data folder directly) <br>
# (Approx Wait Time: 5 min, 53s)

# %%
# %%time
print("FETCHING CANDIDATES!")
candidates_list = []

for index, row in constituency_df.iterrows():
    temp_df = get_candidates(row['district'], row['state'], base_urls[row['year']]+row['thelink'], row['year'])
    candidates_list.append(temp_df)
    
candidates_df = pd.concat(candidates_list)
print("PROCESS COMPLETED!")
# Out:
# FETCHING CANDIDATES!
# PROCESS COMPLETED!
# CPU times: user 22.2 s, sys: 1.2 s, total: 23.4 s
# Wall time: 10min 2s

# %% [markdown]
# #### Wrapping Up and writing to CSV

# %%
print(candidates_df.count())
candidates_df[len(candidates_df)-100:len(candidates_df)].head(3)
candidates_df.to_csv("data/candidates1.csv")
# Out:
# Age               19520
# Assets_Rs         19520
# Constituency      19520
# Criminal_Cases    19520
# Education         19520
# Liabilities_Rs    19520
# Link              19520
# Name              19520
# Party             19520
# State             19520
# Winner            19520
# Year              19520
# dtype: int64

# %% [markdown]
# Above results how the number of values in each column. As the data count is uniform across each column, we can conclude the data scraping has been successfully done.

# %% [markdown]
# ## 3.2 DATA DESCRIPTION

# %% [markdown]
# The dataset comprising of the data of candidates who contested the Indian General Elections in 2004, 2009 and 2014.<br>
# We have a dataset of total 19520 candidates across 15 years. (19520 rows)
# The dataset consists of 13 columns. The columns (features) have been described below:

# %% [markdown]
#  1. <b>Unnamed: 0 : </b> Row Number
#  2. <b>Age : </b> The name of the candidate (String)
#  3. <b> Assets_Rs : </b> Total declared assets owned by the candidates in Rupees (Rs.) (Continuous)
#  4. <b>Constituency : </b> The name of the constituency the candidate is contesting from (String)
#  5. <b> Criminal_Cases : </b> The number of registered criminal cases against the candidate in the Indian Court (Continuous)
#  6. <b>Education : </b> Education Level of the Candidate. 7 Different Values: <br>
#      1. Doctorate : Has a PhD
#      2. Post Graduate : Has a Master's degree
#      3. Graduate : Has a Bachelor's degree
#      4. 12th Pass : Completed School Education, No college education
#      5. 10th Pass : School Education until 10th Grade
#      6. 8th Pass : School Education until 8th Grade
#      7. 5th Pass : School Education until 5th Grade
#      8. Literate : Can read and write, no formal education
#      9. Illiterate : Cannot read or write
#      10. Others : Other Educational Qualifications
#      11. Not Given : No mention of Educational Qualifications
#  7. <b>Liabilities_Rs : </b> The amount of Liabilities owed by the candidate in Rupees (Rs.)
#  9. <b>Name : </b> The Name of the Candidate
#  10. <b>Party : </b> The political party it represents (Most of the names are abbreviated)
#  11. <b>State : </b> The state from which the candidate is contesting from
#  12. <b>Year : </b> The year in which the data was collected
#  13. <b>Winner : </b> Whether the candidate won or lost (0 - Lost, 1 - Won) (Identifier)

# %% [markdown]
# ## 3.3 DATA PREPROCESSING

# %% [markdown]
# The data collected from the website is highly disorganized. To make sure the project and the machine learning model results are correct, certain data cleaning procedures were undertaken. They have been explained below:

# %% [markdown]
#  ### 3.3.1 Checking for Null values

# %%
df = pd.read_csv("data/candidates1.csv") #Read "candidates.csv for already stored dataset"
df[df.isnull().any(axis=1)]  #checking and removing null values=
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Assets_Rs, Constituency, Criminal_Cases, Education, Liabilities_Rs, Link, Name, Party, State, Winner, Year]
# Index: []

# %% [markdown]
# ### 3.3.2 Uniform Typecase:

# %% [markdown]
# Let's take a look at our given dataset:

# %%
df.head(10)
# Out:
#    Unnamed: 0  Age Assets_Rs               Constituency  Criminal_Cases  \
# 0           0   65   5926740  Andaman & Nicobar Islands               0
# 1           1   61   7876500  Andaman & Nicobar Islands               0
# 2           2   50   3070000  Andaman & Nicobar Islands               0
# 3           3   54   1250619  Andaman & Nicobar Islands               0
# 4           4   28      3000  Andaman & Nicobar Islands               0
# 5           5   66   6166416  Andaman & Nicobar Islands               0
# 6           6   37     36200  Andaman & Nicobar Islands               0
# 7           7   51    472440  Andaman & Nicobar Islands               1
# 8           8   65   7752141  Andaman & Nicobar Islands               0
# 9           9   49    772588  Andaman & Nicobar Islands               0
#
#        Education  Liabilities_Rs                           Link  \
# 0  Post Graduate          272061   candidate.php?candidate_id=1
# 1       Graduate           65000   candidate.php?candidate_id=7
# 2       Graduate               0  candidate.php?candidate_id=10
# 3       Graduate          128710   candidate.php?candidate_id=2
# 4      Not Given               0   candidate.php?candidate_id=6
# 5      Doctorate           67070   candidate.php?candidate_id=8
# 6       Graduate               0   candidate.php?candidate_id=9
# 7       8th Pass           73878  candidate.php?candidate_id=11
# 8       Literate               0  candidate.php?candidate_id=12
# 9       Literate          188000   candidate.php?candidate_id=5
#
#                     Name       Party                      State  Winner  Year
# 0      MANORANJAN BHAKTA         INC  ANDAMAN & NICOBAR ISLANDS       1  2004
# 1             A K BISWAS         BSP  ANDAMAN & NICOBAR ISLANDS       0  2004
# 2       ASIT BARAN DUTTA         IND  ANDAMAN & NICOBAR ISLANDS       0  2004
# 3        BISHNU PADA RAY         BJP  ANDAMAN & NICOBAR ISLANDS       0  2004
# 4          DEEPAK BISWAS         IND  ANDAMAN & NICOBAR ISLANDS       0  2004
# 5           DR SHANMUGAM       LJNSP  ANDAMAN & NICOBAR ISLANDS       0  2004
# 6  GOUR CHANDRA MAJUMDER         IND  ANDAMAN & NICOBAR ISLANDS       0  2004
# 7            K KALIMUTHU         IND  ANDAMAN & NICOBAR ISLANDS       0  2004
# 8              K PERUMAL         SWD  ANDAMAN & NICOBAR ISLANDS       0  2004
# 9             N K P NAIR  CPI(ML)(L)  ANDAMAN & NICOBAR ISLANDS       0  2004

# %% [markdown]
# <br><b>For uniformity, converting the values in 'Party' and 'Name' to lowercase

# %%
df["Name"] = df["Name"].apply(lambda x: x.lower())
df["Party"] = df["Party"].apply(lambda x: x.lower())
df.head()
# Out:
#    Unnamed: 0  Age Assets_Rs               Constituency  Criminal_Cases  \
# 0           0   65   5926740  Andaman & Nicobar Islands               0
# 1           1   61   7876500  Andaman & Nicobar Islands               0
# 2           2   50   3070000  Andaman & Nicobar Islands               0
# 3           3   54   1250619  Andaman & Nicobar Islands               0
# 4           4   28      3000  Andaman & Nicobar Islands               0
#
#        Education  Liabilities_Rs                           Link  \
# 0  Post Graduate          272061   candidate.php?candidate_id=1
# 1       Graduate           65000   candidate.php?candidate_id=7
# 2       Graduate               0  candidate.php?candidate_id=10
# 3       Graduate          128710   candidate.php?candidate_id=2
# 4      Not Given               0   candidate.php?candidate_id=6
#
#                 Name Party                      State  Winner  Year
# 0  manoranjan bhakta   inc  ANDAMAN & NICOBAR ISLANDS       1  2004
# 1         a k biswas   bsp  ANDAMAN & NICOBAR ISLANDS       0  2004
# 2   asit baran dutta   ind  ANDAMAN & NICOBAR ISLANDS       0  2004
# 3    bishnu pada ray   bjp  ANDAMAN & NICOBAR ISLANDS       0  2004
# 4      deepak biswas   ind  ANDAMAN & NICOBAR ISLANDS       0  2004

# %% [markdown]
# ### 3.3.3 Removing NULL and values

# %% [markdown]
# <br><b>The constituency name can be same for two different constituencies in two different state. This would lead to ambiguity in our calculation. Making a new column 'state_constituency' and combining the state and constituency for the candidate.

# %%
df["state_constituency"] = df["Constituency"].apply(lambda x: x.lower()) + df["State"].apply(lambda x: x.lower())

# %% [markdown]
# <b><br> Some candidates failed to declare their Asset worth. The value for such cases have been listed as 'Nil'. Others have mentioned their worth as '0'.  <br> Removing 'Nil' and '0' rows from the dataset:

# %%
df = df[df["Assets_Rs"] != "Nil"] #Remove 'Nil' asset values
df = df[df["Assets_Rs"] != 0] # Remove '0' values

# %%
print("New length of dataset: ", len(df))
# Out:
# New length of dataset:  18794

# %% [markdown]
# ### 3.3.4 Type Conversion and Feature Scaling

# %% [markdown]
# <b><br> Converting all Assets_Rs and Liabilities_Rs values to int. <br>
#     Taking log of Assets_Rs. and Liabilities_Rs column for reducing computation time and simpler calculation </b> <br>
#
# (Average wait time: 38 seconds)

# %%
# %%time
print("STARTING PROCESS")
for i,r in df.iterrows():
    try:
        df.loc[i, 'Assets_Rs'] = int(r.Assets_Rs)
        df.loc[i, 'Liabilities_Rs'] = int(r.Liabilities_Rs)
    except:
        df.loc[i, 'Assets_Rs'] = int(0)
        
df["assets_"] = np.log(df["Assets_Rs"])
df["liabilities_"] = np.log(df[df["Liabilities_Rs"]!=0]["Liabilities_Rs"]) #only take log of non-zero values
df.loc[df["liabilities_"].isnull(), "liabilities_"] = 0
print("PROCESS COMPLETED!")
# Out:
# STARTING PROCESS
# PROCESS COMPLETED!
# CPU times: user 50.3 s, sys: 228 ms, total: 50.5 s
# Wall time: 50.7 s

# %% [markdown]
# ### 3.3.5 Feature Label Encoding

# %% [markdown]
# #### Encoding 'state_constituency', 'Party' and 'Education'  features

# %%
le = preprocessing.LabelEncoder()

le.fit(df.state_constituency)
df['constituency_']=le.transform(df.state_constituency)

le.fit(df.Party)
df['party_']=le.transform(df.Party)

le.fit(df.Education)
df['education_']=le.transform(df.Education)

print("Final look at cleaned data:")
df.head(5)
# Out:
# Final look at cleaned data:
#    Unnamed: 0  Age  Assets_Rs               Constituency  Criminal_Cases  \
# 0           0   65    5926740  Andaman & Nicobar Islands               0
# 1           1   61    7876500  Andaman & Nicobar Islands               0
# 2           2   50    3070000  Andaman & Nicobar Islands               0
# 3           3   54    1250619  Andaman & Nicobar Islands               0
# 4           4   28       3000  Andaman & Nicobar Islands               0
#
#        Education  Liabilities_Rs                           Link  \
# 0  Post Graduate          272061   candidate.php?candidate_id=1
# 1       Graduate           65000   candidate.php?candidate_id=7
# 2       Graduate               0  candidate.php?candidate_id=10
# 3       Graduate          128710   candidate.php?candidate_id=2
# 4      Not Given               0   candidate.php?candidate_id=6
#
#                 Name Party                      State  Winner  Year  \
# 0  manoranjan bhakta   inc  ANDAMAN & NICOBAR ISLANDS       1  2004
# 1         a k biswas   bsp  ANDAMAN & NICOBAR ISLANDS       0  2004
# 2   asit baran dutta   ind  ANDAMAN & NICOBAR ISLANDS       0  2004
# 3    bishnu pada ray   bjp  ANDAMAN & NICOBAR ISLANDS       0  2004
# 4      deepak biswas   ind  ANDAMAN & NICOBAR ISLANDS       0  2004
#
#                                   state_constituency    assets_  liabilities_  \
# 0  andaman & nicobar islandsandaman & nicobar isl...  15.594985     12.513782
# 1  andaman & nicobar islandsandaman & nicobar isl...  15.879394     11.082143
# 2  andaman & nicobar islandsandaman & nicobar isl...  14.937188      0.000000
# 3  andaman & nicobar islandsandaman & nicobar isl...  14.039149     11.765317
# 4  andaman & nicobar islandsandaman & nicobar isl...   8.006368      0.000000
#
#    constituency_  party_  education_
# 0             38     291          11
# 1             38     212           5
# 2             38     292           5
# 3             38     175           5
# 4             38     292           9

# %% [markdown]
# ## 3.4 FEATURE CALCULATION

# %% [markdown]
# #### Calculating three features from  existing data:
# 1. Incumbency of candidate
# 2. Party Type : Whether the candidate belongs to a national party, state recognized party, unrecognized party or is an independent candidate (No affiliation to any political party)
# 3. Inclination: Whether the candidate is inclined to a left wing or right wing politicaL; ideology

# %% [markdown]
# ### 3.4.1 Calculating Incumbency Values <br>
#
# Due to huge number of discrepancies in the names of candidates, the incumbency value will be calculated based on whether the political party won or lost previously in the same constituency instead of the candidate himself
#
#     -1 = Incumbent Candidate
#      1 = Non-Incumbent/New Candidate
#
# (Average Wait Time: 12 seconds)

# %%
# %%time 
yrs = [2014, 2009, 2004]
df["Incumbency"] = 1
print("STARTING PROCESS:")
for y in range(len(yrs)-1):   # looping over only the last N-1 years
    for c in df["state_constituency"].unique():
        win_prty = list(df[(df["Year"]==yrs[y+1]) & (df["Winner"]==1) & (df["state_constituency"]==c)]["Party"].unique())
        df.loc[(df["Year"]==yrs[y]) & (df["state_constituency"]==c) & (df["Party"].isin(win_prty)), "Incumbency"] = -1
    print("Calculated for year :", y)
print("PROCESS COMPLETED!")
# Out:
# STARTING PROCESS:
# Calculated for year : 0
# Calculated for year : 1
# PROCESS COMPLETED!
# CPU times: user 10 s, sys: 33.8 ms, total: 10.1 s
# Wall time: 10.1 s

# %% [markdown]
# ### 3.4.2 Calculating Political Party Type

# %% [markdown]
# #### Political Parties in India can be classified as:
# #### 1. National Party:
#
# A registered party is recognized as a national party only if it fulfils any one of the following three conditions:
#
# A. A party wins 2% of seats in the Lok Sabha from at least three different states. <br>
# B. At a general election to Lok Sabha or Legislative Assembly, the party polls 6% of votes in any four or more states and in addition it wins four Lok Sabha seats. <br>
# C. A party gets recognition as a state party in four states. [1] <br>
#
# #### 2. State Party:
# A party has to fulfill any of the following conditions for recognition as a state party:
#
# A. A party should win minimum three percent of the total number of seats or a minimum of three seats in the Legislative Assembly. <br>
# B. A party should win at least one seat in the Lok Sabha for every 25 seats or any fraction thereof allotted to that State. <br>
# C. A party should secure at least six percent of the total valid votes polled during general election to a Lok Sabha or State Legislative Assembly and should, in addition, win at least one Lok Sabha, and two Legislative Assembly seats in that election <br>
# D. Under the liberalized criteria, one more clause that it will be eligible for recognition as state party if it secures 8% or more of the total valid votes polled in the state, addition to one seat in any state. [2] <br>
#
# #### 3. Unrecognized Party:
# Neither of the above
#
# #### 4. Further a candidate can Independent (No affiliation to any political party <br> <br>
#
# <b> As of 2019, only 8 political parties have been granted the 'national' status.  <br>
# For the names of state parties, using 'state_parties_performance.csv' which shows the performance of state parties in the recent elections. </b>

# %%
state_parties_file = pd.read_csv("data/state_parties_performance.csv")
state_parties = np.asarray(state_parties_file["Party Abbre"], dtype=str)
state_parties = np.char.lower(state_parties)
national_parties = np.asarray(["BSP","BJP","CPI","CPI(M)","INC","NCP","NPP"], dtype=str)
national_parties = np.char.lower(national_parties)

# %% [markdown]
# #### Making a new column 'party_type': <br>
#     0 = Unrecognized Party
#     1 = National party
#     2 = State Party
#     3 = Independent Candidate (No party affiliation)

# %%
party = df["Party"]
all_parties = party.unique()
df["party_type"]= 0
for i in national_parties:
    df.loc[(party == i) &  (party.isin(national_parties)), "party_type"] = 1

for i in state_parties:
    df.loc[(party== i) &  (party.isin(state_parties)), "party_type"] = 2

#independent candidates (no affiliation to any party)
df.loc[(party== "ind"), "party_type"] = 3

# %% [markdown]
# ### 3.4.3 Determining candidate's political inclination:
#
# Political parties in India can be left leaning, center leaning, or right leaning. Further there can be several subcategories in political ideologies like left-to-center or far-right or far-left. Determining these subcategories is difficult due to lack of data on the web. Further many political parties in India do not follow a strict ideology when it comes to politics as it is evident in the past. Many political parties also tend to join alliances with opposing views for other gains. <br>
# For the sake of this project, dividing the political parties in 4 categories <br>
#     1. Left Leaning  = 1
#     2. Right Leaning = 2
#     3. Center = 3
#     4. Independent Candidate(No affiliation to any political party/inclination Unknown) = 0

# %%
left_wing = ["inc","rjd", "ncp", "rld", "jmm", "jknc", "mahan dal", "iuml" "socialist janata (democratic)", "kc(m)", "rsp", "bpf","cpi", "jd(s)", "inld", "bsp", "sjp(r)"]
right_wing = ["bjp","shs", "aiadmk", "jd(u)", "sad", "pmk", "ljp", "dmdk", "agp", "ajsu party", "puthiya tamilagam", "all india n.r. congress", "pt", "pnk", "bpf", "kec(m)", "National Loktantrik Party"]

# %%
df["inclination_"]= 3
for i in left_wing:
    df.loc[(party == i) &  (party.isin(left_wing)), "inclination_"] = 1

for i in right_wing:
    df.loc[(party== i) &  (party.isin(right_wing)), "inclination_"] = 2

#independent candidates (no affiliation to any party)
df.loc[(party== "ind"), "inclination_"] = 0

# %% [markdown]
# #### Final look at the new dataset:

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age  Assets_Rs               Constituency  Criminal_Cases  \
# 0           0   65    5926740  Andaman & Nicobar Islands               0
# 1           1   61    7876500  Andaman & Nicobar Islands               0
# 2           2   50    3070000  Andaman & Nicobar Islands               0
# 3           3   54    1250619  Andaman & Nicobar Islands               0
# 4           4   28       3000  Andaman & Nicobar Islands               0
#
#        Education  Liabilities_Rs                           Link  \
# 0  Post Graduate          272061   candidate.php?candidate_id=1
# 1       Graduate           65000   candidate.php?candidate_id=7
# 2       Graduate               0  candidate.php?candidate_id=10
# 3       Graduate          128710   candidate.php?candidate_id=2
# 4      Not Given               0   candidate.php?candidate_id=6
#
#                 Name Party  ...  Year  \
# 0  manoranjan bhakta   inc  ...  2004
# 1         a k biswas   bsp  ...  2004
# 2   asit baran dutta   ind  ...  2004
# 3    bishnu pada ray   bjp  ...  2004
# 4      deepak biswas   ind  ...  2004
#
#                                   state_constituency    assets_ liabilities_  \
# 0  andaman & nicobar islandsandaman & nicobar isl...  15.594985    12.513782
# 1  andaman & nicobar islandsandaman & nicobar isl...  15.879394    11.082143
# 2  andaman & nicobar islandsandaman & nicobar isl...  14.937188     0.000000
# 3  andaman & nicobar islandsandaman & nicobar isl...  14.039149    11.765317
# 4  andaman & nicobar islandsandaman & nicobar isl...   8.006368     0.000000
#
#    constituency_  party_  education_  Incumbency  party_type  inclination_
# 0             38     291          11           1           1             1
# 1             38     212           5           1           1             1
# 2             38     292           5           1           3             0
# 3             38     175           5           1           1             2
# 4             38     292           9           1           3             0
#
# [5 rows x 22 columns]

# %% [markdown]
# # 4. DATA ANALYSIS FOR FEATURE SELECTION

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

plt.gcf().set_size_inches(10, 10)

# %% [markdown]
# ### Based upon the above heatmap, The best features to include in the training set will be:
#
#
# 1. assets_
# 2. Liabilities_Rs
# 3. education_
# 4. party_
# 5. Criminal_Cases
# 6. Incumbency
# 7. constituency_
# 8. Year
# 9. party_type
# 10. inclination_

# %% [markdown]
# # 5. EXPERIMENTS AND CALCULATIONS

# %% [markdown]
# ### 5.1 The Methodology

# %% [markdown]
# For this project, we are creating a regression function $f(c)$ $-> y $ where $c$ denotes candidates $c_1$, $c_2$ , $c_3$ $...$ $c_n$ for all candidates $n$ and y is the 'score' each candidate gets based on the features we train the model on. <br>
# We can now further compare the candidates such that $f(c_1)$ > $f(c_2)$ > $f(c_3)$ etc. for $y_1$>$y_2$>$y_3$ and tell how good a candidate is and what are his chances of winning. <br> <br>
#
# For any candidate, $y$ (score) can be calculated by: <br>
# $$y = \theta_1 x_1 + \theta_2 x_2 + \theta_3 x_3 ... \theta_n x_n $$
#
# for n features, where $x_i$ is the feature and $\theta_i$ the corresponding coefficient/weight
#
# Further as we use the 2014 elections data as the test data, we can determine how unexpectedly skewed the election was towards people who had a lower chance of winning <br>
#
# We are also determining the feature importance of each feature using random forest regressor to determine which factors influence the chances of winning from most to least

# %% [markdown]
# #### The 10 features we are basing our calculations on are:
#
# 1. assets_
# 2. Liabilities_Rs
# 3. education_
# 4. party_
# 5. Criminal_Cases
# 6. Incumbency
# 7. constituency_
# 8. Year
# 9. party_type
# 10. inclination_

# %% [markdown]
# ## 5.2 Experiments

# %% [markdown]
# ### 5.2.1 Data Preparation

# %% [markdown]
# #### Gathering required data and splitting the data into train and test data
# #### For the project, taking 2004 and 2009 data as the train data and 2014 data as the test data

# %%
cols = ['assets_','liabilities_','education_','party_','Criminal_Cases','Incumbency','constituency_','Year','party_type', "inclination_"]
target=['Winner']

X_train, X_test = df[df["Year"]!=2014][cols+target],df[df["Year"]==2014][cols+target]

print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 10663 samples.
# Testing set has 8131 samples.

# %% [markdown]
# ### 5.2.2 Calculating Feature Importance using Random Forest Regressor
#
# (Approx. Wait Time : 15 seconds)

# %%
# %%time
print("Starting Random Forest!")
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(X_train[cols], np.ravel(X_train[target]));
pred_rf = rf.predict(X_test[cols])
print("Process Complete!")
# Out:
# Starting Random Forest!
# Process Complete!
# CPU times: user 15.3 s, sys: 50.1 ms, total: 15.3 s
# Wall time: 15.3 s

# %%
feature_score = sorted(map(lambda x: round(x, 4), rf.feature_importances_),reverse=True)
print("Features sorted by their score:")
sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), cols), 
             reverse=True)
# Out:
# Features sorted by their score:
# [(0.3054, 'assets_'),
#  (0.1843, 'constituency_'),
#  (0.1508, 'party_'),
#  (0.1145, 'liabilities_'),
#  (0.0704, 'education_'),
#  (0.0411, 'Criminal_Cases'),
#  (0.0372, 'party_type'),
#  (0.036, 'inclination_'),
#  (0.0349, 'Year'),
#  (0.0254, 'Incumbency')]

# %% [markdown]
# #### Visualizing Feature Scores:

# %%
feature_score_dict={}
for i,j in zip(cols,rf.feature_importances_):
    feature_score_dict[i]=j
df_fi=pd.DataFrame(feature_score_dict.items(), columns=['name', 'value'])

df_fi=df_fi.sort_values('value', axis=0,ascending=False)

fig, ax = plt.subplots(figsize=(9, 9))

ax=sns.barplot(x="name", y="value",data=df_fi, palette=sns.light_palette("red", reverse=True,n_colors=10))
for item in ax.get_xticklabels():
    item.set_rotation(20)
ax.set(xlabel='Decision feature', ylabel='Importance ratio')
# Out:
# [Text(0, 0.5, 'Importance ratio'), Text(0.5, 0, 'Decision feature')]

# %% [markdown]
# The results above show that a person's declared monetary assets are the most important feature in predicting the outcome followed by which state and constituency he is running from.

# %% [markdown]
# ## 5.3 Defining the Regression Function and Calculating the Candidate Score

# %% [markdown]
# ### 5.3.1 Initializing the trainer and fitting values

# %%
reg = Ridge(alpha=1).fit(X_train[cols], X_train[target])

# %% [markdown]
# ### 5.3.2 Predicting test values values

# %%
y_pred = reg.predict(X_test[cols])

# %% [markdown]
# ### 5.3.3 Classifying Predictions

# %%
b_pred = y_pred
b_pred[b_pred < 0.5] = 0
b_pred[b_pred >= 0.5] = 1

# %%
len(y_pred)
# Out:
# 8131

# %% [markdown]
# ### 5.3.3 Calculating Metrics

# %% [markdown]
# Instead of calculating accuracy score, a balanced accuracy score would be a better fir for our dataset

# %% [markdown]
# #### The balanced accuracy in binary and multi-class classification problems to deal with imbalanced datasets. It is defined as the average of recall obtained on each class.

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score
print("Balanced Accuracy Score = ",balanced_accuracy_score(b_pred, X_test[target]))
# Out:
# Balanced Accuracy Score =  0.6955672646008819

# %% [markdown]
# ### 5.3.3 Calculating Coefficients/Weights of our features

# %%
coef = sorted((reg.coef_[0]), reverse = True)
print("Weights for features (in decreasing order) are:")
print()
for i,j in zip(cols,coef):
    print(i,(j))
# Out:
# Weights for features (in decreasing order) are:
#
# assets_ 0.02830915104499613
# liabilities_ 0.010019119777405936
# education_ 0.002322136577426861
# party_ 0.0012269708767652233
# Criminal_Cases 1.9501397869138875e-05
# Incumbency -0.0001121358027525403
# constituency_ -0.005647708455724299
# Year -0.018559634411151653
# party_type -0.027873440636437114
# inclination_ -0.16348607433891102

# %%
coef[3] = 0
coef[1] = coef[1] * -1

# %% [markdown]
# ### 5.3.4 Calculating Score for each candidate:

# %% [markdown]
# For any candidate, $y$ (score) can be calculated by: <br>
# $$y = \theta_1 x_1 + \theta_2 x_2 + \theta_3 x_3 ... \theta_n x_n $$

# %%
y_score_dict = {}
for i,j in zip(cols,rf.feature_importances_):
    y_score_dict[i]=j
df_score=pd.DataFrame(y_score_dict.items(), columns=['col', 'score'])
df_score1 = df_score.transpose()
df_score1  = df_score1[1:]
df2 = df[cols]
df3 = pd.DataFrame(np.array(df2.values * df_score1.values))
df["score_"] = 0
df["score_"] = df3.sum(axis = 1)
new_df = df[~df["score_"].isnull()]

# %%
print("Scores for each candidate are:")
new_df
# Out:
# Scores for each candidate are:
#        Unnamed: 0  Age  Assets_Rs               Constituency  Criminal_Cases  \
# 0               0   65    5926740  Andaman & Nicobar Islands               0
# 1               1   61    7876500  Andaman & Nicobar Islands               0
# 2               2   50    3070000  Andaman & Nicobar Islands               0
# 3               3   54    1250619  Andaman & Nicobar Islands               0
# 4               4   28       3000  Andaman & Nicobar Islands               0
# 5               5   66    6166416  Andaman & Nicobar Islands               0
# 6               6   37      36200  Andaman & Nicobar Islands               0
# 7               7   51     472440  Andaman & Nicobar Islands               1
# 8               8   65    7752141  Andaman & Nicobar Islands               0
# 9               9   49     772588  Andaman & Nicobar Islands               0
# 10             10   40      59977  Andaman & Nicobar Islands               1
# 11             11   46    2435276  Andaman & Nicobar Islands               0
# 12              0   59    7550000                   Adilabad               0
# 13              1   42   11580000                   Adilabad               0
# 16              0   59    6763811                 Amalapuram               0
# 17              1   51     988000                 Amalapuram               0
# 18              2   59     236200                 Amalapuram               0
# 19              3   40     340000                 Amalapuram               0
# 20              0   58    5396505                 Anakapalli               0
# 22              0   47    3890000                  Anantapur               0
# 23              1   32     505000                  Anantapur               0
# 24              2   42      33698                  Anantapur               0
# 25              3   41      97000                  Anantapur               0
# 26              4   44      54000                  Anantapur               0
# 27              5   39     300320                  Anantapur               0
# 28              6   32     120000                  Anantapur               0
# 29              0   44   40907640                    Bapatla               0
# 30              1    0      70000                    Bapatla               0
# 31              2   67   98790428                    Bapatla               0
# 32              3   40    3298000                    Bapatla               0
# ...           ...  ...        ...                        ...             ...
# 18764           0   74   27136042                     RAMPUR               0
# 18765           1   67   62120983                     RAMPUR               0
# 18766           2   51    2513782                     RAMPUR               0
# 18767           3   44    1705000                     RAMPUR               0
# 18768           4   49    3212000                     RAMPUR               0
# 18769           5   27     160344                     RAMPUR               0
# 18770           6   76   36512409                     RAMPUR               0
# 18771           7   43      95000                     RAMPUR               0
# 18772           8   53  571146438                     RAMPUR               0
# 18773           9   49    2118955                     RAMPUR               0
# 18774          10   45     477625                     RAMPUR               0
# 18775          11   32   33048000                     RAMPUR               0
# 18776           0   41    3687361                ROBERTSGANJ               0
# 18777           1   29     426038                ROBERTSGANJ               1
# 18778           2   50    1180000                ROBERTSGANJ               0
# 18779           3   60   21571918                ROBERTSGANJ               1
# 18780           4   40    1054898                ROBERTSGANJ               0
# 18781           5   51    1230000                ROBERTSGANJ               0
# 18782           6   70    3229000                ROBERTSGANJ               0
# 18783           7   62   17278483                ROBERTSGANJ               0
# 18784           8   35     105000                ROBERTSGANJ               0
# 18785           9   44    1024540                ROBERTSGANJ               0
# 18786          10   43    6825000                ROBERTSGANJ               0
# 18787          11   70   12227165                ROBERTSGANJ               0
# 18788          12   52     321000                ROBERTSGANJ               1
# 18789          13   55   10642000                ROBERTSGANJ               1
# 18790           0   39   35406431                 SAHARANPUR               0
# 18791           1   46    4750000                 SAHARANPUR               3
# 18792           2   43    3411840                 SAHARANPUR               0
# 18793           3   43   47166093                 SAHARANPUR               5
#
#                    Education  Liabilities_Rs                             Link  \
# 0              Post Graduate          272061     candidate.php?candidate_id=1
# 1                   Graduate           65000     candidate.php?candidate_id=7
# 2                   Graduate               0    candidate.php?candidate_id=10
# 3                   Graduate          128710     candidate.php?candidate_id=2
# 4                  Not Given               0     candidate.php?candidate_id=6
# 5                  Doctorate           67070     candidate.php?candidate_id=8
# 6                   Graduate               0     candidate.php?candidate_id=9
# 7                   8th Pass           73878    candidate.php?candidate_id=11
# 8                   Literate               0    candidate.php?candidate_id=12
# 9                   Literate          188000     candidate.php?candidate_id=5
# 10                 Not Given           35000     candidate.php?candidate_id=4
# 11             Post Graduate               0     candidate.php?candidate_id=3
# 12     Graduate Professional          120000    candidate.php?candidate_id=13
# 13                    Others         1247053    candidate.php?candidate_id=14
# 16                    Others          748000    candidate.php?candidate_id=21
# 17                  Graduate           60000    candidate.php?candidate_id=18
# 18                    Others           35000    candidate.php?candidate_id=19
# 19                 Not Given               0    candidate.php?candidate_id=20
# 20                  Graduate          246000    candidate.php?candidate_id=22
# 22             Post Graduate          437636    candidate.php?candidate_id=25
# 23                  Graduate               0    candidate.php?candidate_id=30
# 24                  Graduate               0    candidate.php?candidate_id=31
# 25                  Graduate            9000    candidate.php?candidate_id=27
# 26                 12th Pass               0    candidate.php?candidate_id=29
# 27             Post Graduate           88000    candidate.php?candidate_id=26
# 28                 Not Given               0    candidate.php?candidate_id=28
# 29                    Others         5212201    candidate.php?candidate_id=32
# 30                  Graduate               0    candidate.php?candidate_id=34
# 31                  Graduate               0    candidate.php?candidate_id=33
# 32                    Others          200000    candidate.php?candidate_id=36
# ...                      ...             ...                              ...
# 18764              Doctorate         1614820  candidate.php?candidate_id=3180
# 18765              10th Pass         3790727  candidate.php?candidate_id=3181
# 18766          Post Graduate               0  candidate.php?candidate_id=3182
# 18767               5th Pass               0  candidate.php?candidate_id=3184
# 18768               8th Pass               0  candidate.php?candidate_id=3178
# 18769              Not Given               0  candidate.php?candidate_id=3185
# 18770          Post Graduate               0  candidate.php?candidate_id=3177
# 18771              Not Given               0  candidate.php?candidate_id=3186
# 18772          Post Graduate         7745000  candidate.php?candidate_id=3179
# 18773               Graduate               0  candidate.php?candidate_id=3183
# 18774              12th Pass               0   candidate.php?candidate_id=232
# 18775               Literate               0  candidate.php?candidate_id=3187
# 18776               5th Pass           55313  candidate.php?candidate_id=9290
# 18777               Graduate               0  candidate.php?candidate_id=9727
# 18778  Graduate Professional               0  candidate.php?candidate_id=9295
# 18779  Graduate Professional         1425250  candidate.php?candidate_id=9293
# 18780             Illiterate               0  candidate.php?candidate_id=9296
# 18781              12th Pass               0  candidate.php?candidate_id=9725
# 18782              12th Pass               0  candidate.php?candidate_id=9729
# 18783               Literate               0  candidate.php?candidate_id=9294
# 18784               8th Pass               0  candidate.php?candidate_id=9728
# 18785          Post Graduate               0  candidate.php?candidate_id=9726
# 18786              Not Given          550000  candidate.php?candidate_id=9292
# 18787               Graduate          596180  candidate.php?candidate_id=9730
# 18788               Literate               0  candidate.php?candidate_id=9291
# 18789               Literate               0  candidate.php?candidate_id=9289
# 18790          Post Graduate               0   candidate.php?candidate_id=685
# 18791               Literate               0  candidate.php?candidate_id=1739
# 18792  Graduate Professional           42000  candidate.php?candidate_id=1748
# 18793              12th Pass         2012262   candidate.php?candidate_id=684
#
#                              Name                                  Party  ...  \
# 0               manoranjan bhakta                                    inc  ...
# 1                      a k biswas                                    bsp  ...
# 2                asit baran dutta                                    ind  ...
# 3                 bishnu pada ray                                    bjp  ...
# 4                   deepak biswas                                    ind  ...
# 5                    dr shanmugam                                  ljnsp  ...
# 6           gour chandra majumder                                    ind  ...
# 7                     k kalimuthu                                    ind  ...
# 8                       k perumal                                    swd  ...
# 9                      n k p nair                             cpi(ml)(l)  ...
# 10               r s uma bharathy                                    ncp  ...
# 11             tapan kumar bepari                                    cpm  ...
# 12     madhusudhan reddy thakkala                                    trs  ...
# 13          dr s venugopala chary                                    tdp  ...
# 16               d. muralikrishna                                    bsp  ...
# 17           dunna janardhana rao                                    tdp  ...
# 18         muneeswara rao bhupati                                    ind  ...
# 19                 yalangi ramesh                                    ind  ...
# 20          chalapathirao pappala                                    tdp  ...
# 22     anantha venkata rami reddy                                    inc  ...
# 23             a. jagan mohan rao                                    trs  ...
# 24                 b. s. amarnath                                    ind  ...
# 25          gaddala nagabhushanam                                    bsp  ...
# 26                 k. venkatesulu                                   ppoi  ...
# 27             kalava srinivasulu                                    tdp  ...
# 28              yatham pothalaiah                                    ind  ...
# 29       daggubati purandareswari                                    inc  ...
# 30      chellamalla venkata reddy                                    trs  ...
# 31            daggubati ramanaidu                                    tdp  ...
# 32               inaganti apparao                                    ind  ...
# ...                           ...                                    ...  ...
# 18764             dr. nepal singh                                    bjp  ...
# 18765                akbar husain                                    bsp  ...
# 18766                akbar masood                                    ind  ...
# 18767         jagdish saran sagar                                    ind  ...
# 18768                    jagmohan                                    ind  ...
# 18769                jannat nisha             all india minorities front  ...
# 18770           naseer ahmad khan                                     sp  ...
# 18771                  naved mian                                    ind  ...
# 18772        nawab kazim ali khan                                    inc  ...
# 18773             syed salman ali                                    aap  ...
# 18774                tejpal singh                                    ind  ...
# 18775              vijendra singh  rashtriya congress (babu jagjivanram)  ...
# 18776                  chhote lal                                    bjp  ...
# 18777           arun singh(chero)                                    ind  ...
# 18778     ashok kumar kannaoujiya                                    cpi  ...
# 18779   bhagwati prasad chaudhary                                    inc  ...
# 18780      gun devi ( gyani devi)                         qaumi ekta dal  ...
# 18781            lawrence anthony                                    ind  ...
# 18782                      mangoi                    bahujan mukti party  ...
# 18783             pakaudi lal kol                                     sp  ...
# 18784                   raj kumar                  shoshit sandesh party  ...
# 18785                  rambriksha                                    ind  ...
# 18786      ravi shankar kannaujia                                    aap  ...
# 18787              s. r. darapuri      all india peoples front (radical)  ...
# 18788                 shankar kol                               cpi(ml)l  ...
# 18789              sharada prasad                                    bsp  ...
# 18790            raghav lakhanpal                                    bjp  ...
# 18791                    cp verma                                    ind  ...
# 18792               hansraj saini                                    ind  ...
# 18793                imran masood                                    inc  ...
#
#                                       state_constituency    assets_  \
# 0      andaman & nicobar islandsandaman & nicobar isl...  15.594985
# 1      andaman & nicobar islandsandaman & nicobar isl...  15.879394
# 2      andaman & nicobar islandsandaman & nicobar isl...  14.937188
# 3      andaman & nicobar islandsandaman & nicobar isl...  14.039149
# 4      andaman & nicobar islandsandaman & nicobar isl...   8.006368
# 5      andaman & nicobar islandsandaman & nicobar isl...  15.634628
# 6      andaman & nicobar islandsandaman & nicobar isl...  10.496814
# 7      andaman & nicobar islandsandaman & nicobar isl...  13.065666
# 8      andaman & nicobar islandsandaman & nicobar isl...  15.863480
# 9      andaman & nicobar islandsandaman & nicobar isl...  13.557501
# 10     andaman & nicobar islandsandaman & nicobar isl...  11.001716
# 11     andaman & nicobar islandsandaman & nicobar isl...  14.705571
# 12                                adilabadandhra pradesh  15.837058
# 13                                adilabadandhra pradesh  16.264790
# 16                              amalapuramandhra pradesh  15.727097
# 17                              amalapuramandhra pradesh  13.803438
# 18                              amalapuramandhra pradesh  12.372434
# 19                              amalapuramandhra pradesh  12.736701
# 20                              anakapalliandhra pradesh  15.501262
# 22                               anantapurandhra pradesh  15.173920
# 23                               anantapurandhra pradesh  13.132314
# 24                               anantapurandhra pradesh  10.425194
# 25                               anantapurandhra pradesh  11.482466
# 26                               anantapurandhra pradesh  10.896739
# 27                               anantapurandhra pradesh  12.612604
# 28                               anantapurandhra pradesh  11.695247
# 29                                 bapatlaandhra pradesh  17.526827
# 30                                 bapatlaandhra pradesh  11.156251
# 31                                 bapatlaandhra pradesh  18.408511
# 32                                 bapatlaandhra pradesh  15.008827
# ...                                                  ...        ...
# 18764                                rampuruttar pradesh  17.116373
# 18765                                rampuruttar pradesh  17.944594
# 18766                                rampuruttar pradesh  14.737299
# 18767                                rampuruttar pradesh  14.349076
# 18768                                rampuruttar pradesh  14.982404
# 18769                                rampuruttar pradesh  11.985077
# 18770                                rampuruttar pradesh  17.413163
# 18771                                rampuruttar pradesh  11.461632
# 18772                                rampuruttar pradesh  20.163156
# 18773                                rampuruttar pradesh  14.566434
# 18774                                rampuruttar pradesh  13.076581
# 18775                                rampuruttar pradesh  17.313472
# 18776                           robertsganjuttar pradesh  15.120422
# 18777                           robertsganjuttar pradesh  12.962284
# 18778                           robertsganjuttar pradesh  13.981025
# 18779                           robertsganjuttar pradesh  16.886903
# 18780                           robertsganjuttar pradesh  13.868955
# 18781                           robertsganjuttar pradesh  14.022525
# 18782                           robertsganjuttar pradesh  14.987683
# 18783                           robertsganjuttar pradesh  16.664973
# 18784                           robertsganjuttar pradesh  11.561716
# 18785                           robertsganjuttar pradesh  13.839754
# 18786                           robertsganjuttar pradesh  15.736103
# 18787                           robertsganjuttar pradesh  16.319171
# 18788                           robertsganjuttar pradesh  12.679196
# 18789                           robertsganjuttar pradesh  16.180319
# 18790                            saharanpuruttar pradesh  17.382404
# 18791                            saharanpuruttar pradesh  15.373655
# 18792                            saharanpuruttar pradesh  15.042762
# 18793                            saharanpuruttar pradesh  17.669186
#
#        liabilities_ constituency_  party_  education_  Incumbency  party_type  \
# 0         12.513782            38     291          11           1           1
# 1         11.082143            38     212           5           1           1
# 2          0.000000            38     292           5           1           3
# 3         11.765317            38     175           5           1           1
# 4          0.000000            38     292           9           1           3
# 5         11.113492            38     404           4           1           0
# 6          0.000000            38     292           5           1           3
# 7         11.210170            38     292           3           1           3
# 8          0.000000            38     768           8           1           0
# 9         12.144197            38     232           8           1           0
# 10        10.463103            38     497           9           1           1
# 11         0.000000            38     234          11           1           0
# 12        11.695247             0     785           6           1           0
# 13        14.036294             0     774          10           1           0
# 16        13.525158            22     212          10           1           1
# 17        11.002100            22     774           5           1           0
# 18        10.463103            22     292          10           1           3
# 19         0.000000            22     292           9           1           3
# 20        12.413087            32     774           5           1           0
# 22        12.989143            35     291          11           1           1
# 23         0.000000            35     785           5           1           0
# 24         0.000000            35     292           5           1           3
# 25         9.104980            35     212           5           1           1
# 26         0.000000            35     545           1           1           0
# 27        11.385092            35     774          11           1           0
# 28         0.000000            35     292           9           1           3
# 29        15.466513            86     291          10           1           1
# 30         0.000000            86     785           5           1           0
# 31         0.000000            86     774           5           1           0
# 32        12.206073            86     292          10           1           3
# ...             ...           ...     ...         ...         ...         ...
# 18764     14.294734           622     175           4           1           1
# 18765     15.148068           622     212           0           1           1
# 18766      0.000000           622     292          11           1           3
# 18767      0.000000           622     292           2           1           3
# 18768      0.000000           622     292           3           1           3
# 18769      0.000000           622      58           9           1           0
# 18770      0.000000           622     750          11          -1           0
# 18771      0.000000           622     292           9           1           3
# 18772     15.862558           622     291          11           1           1
# 18773      0.000000           622       5           5           1           2
# 18774      0.000000           622     292           1           1           3
# 18775      0.000000           622     591           8           1           0
# 18776     10.920763           633     175           2           1           1
# 18777      0.000000           633     292           5           1           3
# 18778      0.000000           633     229           6           1           1
# 18779     14.169858           633     291           6           1           1
# 18780      0.000000           633     569           7           1           0
# 18781      0.000000           633     292           1           1           3
# 18782      0.000000           633      94           1           1           0
# 18783      0.000000           633     750           8          -1           0
# 18784      0.000000           633     731           3           1           0
# 18785      0.000000           633     292          11           1           3
# 18786     13.217674           633       5           9           1           2
# 18787     13.298298           633      60           5           1           0
# 18788      0.000000           633     233           8           1           0
# 18789      0.000000           633     212           8           1           1
# 18790      0.000000           639     175          11           1           1
# 18791      0.000000           639     292           8           1           3
# 18792     10.645425           639     292           6           1           3
# 18793     14.514770           639     291           1           1           1
#
#        inclination_      score_
# 0                 1  127.823890
# 1                 1  115.410026
# 2                 0  125.956561
# 3                 2  109.382235
# 4                 0  124.121770
# 5                 3  144.259792
# 6                 0  124.600649
# 7                 0  126.569245
# 8                 3  198.234990
# 9                 3  118.085068
# 10                1  157.154554
# 11                3  117.557660
# 12                3  194.985945
# 13                3  194.007309
# 16                1  123.774871
# 17                3  122.617415
# 18                0  199.133873
# 19                0  127.196853
# 20                3  199.200744
# 22                1  113.288044
# 23                3  162.041000
# 24                0  199.109369
# 25                1  124.695304
# 26                3  137.527984
# 27                3  207.996661
# 28                0  208.552251
# 29                1  136.574768
# 30                3  133.208047
# 31                3  127.638539
# 32                0  215.316625
# ...             ...         ...
# 18764             2  232.363904
# 18765             1  248.104309
# 18766             0  246.175045
# 18767             0  325.591425
# 18768             0  319.378279
# 18769             3  248.768787
# 18770             3  246.250096
# 18771             0  236.937190
# 18772             1  209.434852
# 18773             3  249.676640
# 18774             0  233.504820
# 18775             3  318.545629
# 18776             2  249.693897
# 18777             0  235.229974
# 18778             1  249.328835
# 18779             1  250.213678
# 18780             3  239.493860
# 18781             0  249.632903
# 18782             3  219.094708
# 18783             3  259.327520
# 18784             3  258.692409
# 18785             0  256.510852
# 18786             3  255.436273
# 18787             3  326.937225
# 18788             3  257.498199
# 18789             1  242.168645
# 18790             2  243.289942
# 18791             0  246.788948
# 18792             0  217.028659
# 18793             1  257.784749
#
# [18073 rows x 23 columns]

# %% [markdown]
# #### Normalizing Scores
# For every $x_i$, <br>
# $$x_i = \frac{(x_i - mean)} {Standard Deviation}$$

# %%
x = new_df["score_"].values #returns a numpy array
x = (x - x.mean())/x.std()
new_df["score_"] = x
# Out:
# /Users/ankushwadhwa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print("Calculated score statistics:")
new_df["score_"].describe()
# Out:
# Calulated score staistics:
# count    1.807300e+04
# mean     3.049504e-16
# std      1.000028e+00
# min     -2.396089e+00
# 25%     -8.041259e-01
# 50%     -2.343944e-02
# 75%      7.569058e-01
# max      3.077088e+00
# Name: score_, dtype: float64

# %% [markdown]
#  ### 5.3.4 Visualizing Score

# %% [markdown]
# Now that we the scores for each candidate, we can perform various operations on it. <br>
# One such experiment can be to compute state-wise and party-wise average score and plot them:

# %% [markdown]
#  ####  Visualizing State-wise average score

# %%
avg_state_score = {}
for i in new_df["State"].unique():
       avg_state_score[i] = new_df[new_df["State"] == i]["score_"].mean()

df_state_score = pd.DataFrame(avg_state_score.items(), columns= ['state','score_avg'])
df_state_score = df_state_score.sort_values(by = "score_avg")
fig, ax = plt.subplots(figsize=(20, 10))
ax=sns.barplot(x="state", y="score_avg",data=df_state_score, palette=sns.dark_palette("red", reverse=False,n_colors=38))
for item in ax.get_xticklabels():
    item.set_rotation(75)
ax.set(xlabel='State', ylabel='Average Score')
# Out:
# [Text(0, 0.5, 'Average Score'), Text(0.5, 0, 'State')]

# %% [markdown]
# We can infer from the above graph that candidates contesting in the states of 'Puducherry' and 'Nagaland' have the worst average scores.<br>
# While candidates in the states of 'Sikkim' and 'Uttarakhand' have the best scores of all States and Union territories in India for three consecutive elections

# %% [markdown]
#  ####  Visualizing Party-wise average score:

# %% [markdown]
# Top 30 Political Parties in India with candidates having the worst chance of winning

# %%
avg_party_score = {}
for i in new_df["Party"].unique():
       avg_party_score[i] = new_df[new_df["Party"] == i]["score_"].mean()

df_party_score = pd.DataFrame(avg_party_score.items(), columns= ['party','score_avg'])
df_party_score = df_party_score.sort_values(by = "score_avg")
fig, ax = plt.subplots(figsize=(20, 10))
ax=sns.barplot(x="party", y="score_avg",data=df_party_score[:30], palette=sns.dark_palette("red", reverse=False,n_colors=38))
for item in ax.get_xticklabels():
    item.set_rotation(75)
ax.set(xlabel='State', ylabel='Average Score')
# Out:
# [Text(0, 0.5, 'Average Score'), Text(0.5, 0, 'State')]

# %% [markdown]
# Top 30 Political Parties in India with candidates having the best chance of winning

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax=sns.barplot(x="party", y="score_avg",data=df_party_score[-30:], palette=sns.dark_palette("red", reverse=False,n_colors=38))
for item in ax.get_xticklabels():
    item.set_rotation(75)
ax.set(xlabel='State', ylabel='Average Score')
# Out:
# [Text(0, 0.5, 'Average Score'), Text(0.5, 0, 'State')]

# %% [markdown]
# We can further compare the average scores of left wing political parties with the right wing and center

# %%
avg_ideology_score = {}
for i in new_df["inclination_"].unique():
       avg_ideology_score[i] = new_df[new_df["inclination_"] == i]["score_"].mean()

df_ideology_score = pd.DataFrame(avg_ideology_score.items(), columns= ['ideology','score_avg'])
df_ideology_score['ideology'] = df_ideology_score['ideology'].replace({0:'Center', 1:'Left-Wing', 2: 'Right Wing', 3:'Independent'})
df_ideology_score = df_ideology_score.sort_values(by = "score_avg")
fig, ax = plt.subplots(figsize=(20, 10))
ax=sns.barplot(x="ideology", y="score_avg",data=df_ideology_score, palette=sns.dark_palette("red", reverse=False,n_colors=5))
for item in ax.get_xticklabels():
    item.set_rotation(75)
ax.set(xlabel='ideology', ylabel='Average Score')
# Out:
# [Text(0, 0.5, 'Average Score'), Text(0.5, 0, 'ideology')]

# %% [markdown]
# As we can see above, the average scores of all political parties are in the range -0.3 to 0.3 and they vary by a small margin. So, the results are either inconclusive in the case or Indian election ecosystem doesn't depend significantly on a candidate's political ideology. (which has been evident in the past)

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# We can calculate the F1 score and precision of our model to see further how accurate the calculations are. <br>
# Further, whether the feature selection of the current model (based on 2004 and 2009 elections) goes along with the trend of 2014 elections can be determined by these metrics

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

print(f1_score(X_test[target].values, y_pred))
print(precision_score(X_test[target].values, y_pred))
print(recall_score(X_test[target].values, y_pred))
print(confusion_matrix(X_test[target].values, y_pred))
# Out:
# 0.09688581314878891
# 0.45161290322580644
# 0.05426356589147287
# [[7581   34]
#  [ 488   28]]

# %% [markdown]
# As the F1 score is low for our calculations (~0.1), I conclude that the algorithm and the dataset are not sufficient to determine the outcome of the 2014 elections. <br> <br>
#
# The 2014 general elections in India were the most skewed elections where the outcome was the least expected, catching most of the psephologists by surprised. The sudden emergence of Prime Minister Modi's right-wing BJP and the National Democratic Alliance was unanticipated after a 10 year long administrative rule of the left-wing INC and the United Progressive Alliance. <br> <br>
# <b>The motivation behind this project has always been the unprecedented outcome of 2014 elections. Even though the algorithm and the dataset lags to determine the outcomes, I do hope it highlights the sudden change in the political environment of India in 2014. </b>

# %% [markdown]
# ### The unavailability of the 2019 election results significantly impacts the model. I hope to continue this project after the 2019 election results are released in the public domain

# %% [markdown]
# # 7. References

# %% [markdown]
# 1. Data source: www.myneta.info
# 2. https://carnegieendowment.org/publications/interactive/india-elects-2019
# 3. https://www.news18.com/lok-sabha-elections-2019/key-candidate-list/
# 4. https://eci.gov.in/files/category/262-recognized-state-parties/
# 5. https://eci.gov.in/files/category/267-recognized-national-parties/
# 6. https://en.wikipedia.org/wiki/List_of_United_Progressive_Alliance_candidates_in_the_2014_Indian_general_election
# 7. https://en.wikipedia.org/wiki/List_of_National_Democratic_Alliance_candidates_in_the_2014_Indian_general_election
# 8. https://github.com/cben/mathdown/wiki/math-in-markdown
# 9. https://medium.com/@andykashyap/top-5-tricks-to-make-plots-look-better-9f6e687c1e08
# 10. https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9
# 11. https://blog.datadive.net/selecting-good-features-part-iii-random-forests/
# 12. https://en.wikipedia.org/wiki/Psephology
